# %%
import scipy as sc
from sklearn.ensemble import RandomForestClassifier
clf=RandomForestclassifier(random_state=0)
x=[[1,2,3],
  [2,3,4]]
y=[0,1]
clf.fit(x,y)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_2864\522375557.py in <module>
# ----> 1 clf=RandomForestclassifier(random_state=0)
#       2 x=[[1,2,3],
#       3   [2,3,4]]
#       4 y=[0,1]
#       5 clf.fit(x,y)
#
# NameError: name 'RandomForestclassifier' is not defined

# %%
import pandas as pd

# %%
f=pd.read_csv('one.csv')
f
# Out:
#                   Description Losses  1939/40  1940/41  1941/42  1942/43  \
# 0                  Direct War Losses  360,000      NaN      NaN      NaN
# 1                           Murdered   75,000  100,000  116,000  133,000
# 2          Deaths In Prisons & Camps   69,000  210,000  220,000  266,000
# 3  Deaths Outside of Prisons & Camps      NaN   42,000   71,000  142,000
# 4        Murdered in Eastern Regions      NaN      NaN      NaN      NaN
# 5             Deaths other countries      NaN      NaN      NaN      NaN
# 6                              Total  504,000  352,000  407,000  541,000
#
#    1943/44  1944/45      Total
# 0      NaN  183,000    543,000
# 1   82,000      NaN    506,000
# 2  381,000      NaN  1,146,000
# 3  218,000      NaN    473,000
# 4      NaN  100,000    100,000
# 5      NaN      NaN      2,000
# 6  681,000  270,000  2,770,000

# %%
import os

# %%
os.listdir()
# Out:
# ['....000',
#  '.idea',
#  '.ipynb_checkpoints',
#  '4536693-e3959b336e51e5c4c7afc1426583c6357e2666a3',
#  'Building-a-Simple-Chatbot-in-Python-using-NLTK-master',
#  'classes.py',
#  'classification.ipynb',
#  'Coffee_machine_Python-main',
#  'data.json',
#  'datasets-master',
#  'dictor-master',
#  'Document-Scanner-master',
#  'Dominoes_game_Python-main',
#  'english-words-master',
#  'Face-Detection-in-Python-using-OpenCV-master',
#  'Face-Recognition-master',
#  'Facial-Landmarks-Detection-with-DLIB-master',
#  'Image-Classification-by-Keras-and-Tensorflow-master',
#  'Image-Classification-using-Keras-master',
#  'json file.py',
#  'keras-image-classification-from-scratch-main',
#  'Learn-OpenCV-in-3-hours-master',
#  'learnPython-master',
#  'machine',
#  'magical_universe-master',
#  'Measuring-Size-of-Objects-with-OpenCV-master',
#  'MS12-020-main',
#  'numpy basics.ipynb',
#  'nupy.py',
#  'one.csv',
#  'OpenCV-Python-Tutorials-and-Projects-master',
# ...
